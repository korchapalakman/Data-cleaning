# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
with open ("/Users/vazgenosipov/Desktop/Python/Python Data analys/UNZIP_FOR_NOTEBOOKS_FINAL/DATA/Ames_Housing_Feature_Description.txt", 'r') as f:
    print(f.read())

# this commad helps us to open a file and store it in f
# then we read f

# with operator helps to open and close the file aoutomatically

# name of the feature
# general description 
# proporties
# Out:
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
# ...

# %%
df = pd.read_csv("/Users/vazgenosipov/Desktop/Python/Python Data analys/UNZIP_FOR_NOTEBOOKS_FINAL/DATA/Ames_outliers_removed.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2927 entries, 0 to 2926
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PID              2927 non-null   int64
#  1   MS SubClass      2927 non-null   int64
#  2   MS Zoning        2927 non-null   object
#  3   Lot Frontage     2437 non-null   float64
#  4   Lot Area         2927 non-null   int64
#  5   Street           2927 non-null   object
#  6   Alley            198 non-null    object
#  7   Lot Shape        2927 non-null   object
#  8   Land Contour     2927 non-null   object
#  9   Utilities        2927 non-null   object
#  10  Lot Config       2927 non-null   object
#  11  Land Slope       2927 non-null   object
#  12  Neighborhood     2927 non-null   object
#  13  Condition 1      2927 non-null   object
#  14  Condition 2      2927 non-null   object
#  15  Bldg Type        2927 non-null   object
# ...

# %%
df.head()

# pid is unique identifyer of the df, we already have index
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  526301100           20        RL         141.0     31770   Pave   NaN
# 1  526350040           20        RH          80.0     11622   Pave   NaN
# 2  526351010           20        RL          81.0     14267   Pave   NaN
# 3  526353030           20        RL          93.0     11160   Pave   NaN
# 4  527105010           60        RL          74.0     13830   Pave   NaN
#
#   Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence Misc Feature  \
# 0       IR1          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 1       Reg          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
# 2       IR1          Lvl    AllPub  ...         0     NaN    NaN         Gar2
# 3       Reg          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 4       IR1          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
#
# ...

# %%
df = df.drop("PID", axis=1)

# %%
df.head(1)
# Out:
#    MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 0           20        RL         141.0     31770   Pave   NaN       IR1
#
#   Land Contour Utilities Lot Config  ... Pool Area Pool QC Fence Misc Feature  \
# 0          Lvl    AllPub     Corner  ...         0     NaN   NaN          NaN
#
#   Misc Val Mo Sold  Yr Sold  Sale Type  Sale Condition  SalePrice
# 0        0       5     2010        WD           Normal     215000
#
# [1 rows x 80 columns]

# %%
df.isnull().sum()

# will return the number of missing values in every feature
# Out:
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      490
# Lot Area            0
# Street              0
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 80, dtype: int64

# %%
# percent of a missing columns 

100 * df.isnull().sum() / len (df)
# Out:
# MS SubClass        0.00000
# MS Zoning          0.00000
# Lot Frontage      16.74069
# Lot Area           0.00000
# Street             0.00000
#                     ...
# Mo Sold            0.00000
# Yr Sold            0.00000
# Sale Type          0.00000
# Sale Condition     0.00000
# SalePrice          0.00000
# Length: 80, dtype: float64

# %%
# lets create a function that will create a percentage of what is missing 

def percent_missing(df):
    # will report the percent missing 
    percent_nan = 100 * df.isnull().sum() / len (df)
    
    # will return only values > 0% missing in sorted order
    percent_nan = percent_nan[percent_nan>0].sort_values()
    
    return percent_nan

# %%
# now lets test the function by creating new variable

percent_nan = percent_missing(df)

# %%
percent_nan
# Out:
# Electrical         0.034165
# Garage Area        0.034165
# Total Bsmt SF      0.034165
# Bsmt Unf SF        0.034165
# BsmtFin SF 1       0.034165
# BsmtFin SF 2       0.034165
# Garage Cars        0.034165
# Bsmt Full Bath     0.068329
# Bsmt Half Bath     0.068329
# Mas Vnr Area       0.785787
# Mas Vnr Type       0.785787
# BsmtFin Type 1     2.733174
# Bsmt Qual          2.733174
# Bsmt Cond          2.733174
# BsmtFin Type 2     2.767339
# Bsmt Exposure      2.835668
# Garage Type        5.363854
# Garage Finish      5.432183
# Garage Qual        5.432183
# Garage Cond        5.432183
# Garage Yr Blt      5.432183
# Lot Frontage      16.740690
# Fireplace Qu      48.582166
# Fence             80.457807
# Alley             93.235395
# Misc Feature      96.412709
# Pool QC           99.590024
# dtype: float64

# %%
# visualise them 

# percent_nan.index = will return features name

plt.figure(figsize=(8,4), dpi=200)
sns.barplot(x=percent_nan.index, y=percent_nan)
plt.xticks(rotation = 90) # will rotate the labels 
;
# Out:
# ''

# %%
# lets take a look at features with few missing data points
plt.figure(figsize=(8,4), dpi=200)
sns.barplot(x=percent_nan.index, y=percent_nan)
plt.xticks(rotation = 90) # will rotate the labels 

# will cut to 1 percent of the data on y
plt.ylim(0,1);

# %% [markdown]
# ## Missing small amount of % (columns)

# %%
# the list of columns where the missing values < 1%

percent_nan[percent_nan<1]
# Out:
# Electrical        0.034165
# Garage Area       0.034165
# Total Bsmt SF     0.034165
# Bsmt Unf SF       0.034165
# BsmtFin SF 1      0.034165
# BsmtFin SF 2      0.034165
# Garage Cars       0.034165
# Bsmt Full Bath    0.068329
# Bsmt Half Bath    0.068329
# Mas Vnr Area      0.785787
# Mas Vnr Type      0.785787
# dtype: float64

# %%
# what is the one row in percent of the data

100 / len(df)

# as cane be seen above 
# we are just missing 1-2 rows
# Out:
# 0.0341646737273659

# %%
# lets check this row

# does this row has a missing value for a second column 

df[df["Electrical"].isnull()]
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 1576           80        RL          73.0      9735   Pave   NaN       Reg
#
#      Land Contour Utilities Lot Config  ... Pool Area Pool QC Fence  \
# 1576          Lvl    AllPub     Inside  ...         0     NaN   NaN
#
#      Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  Sale Condition  \
# 1576          NaN        0       5     2008        WD           Normal
#
#       SalePrice
# 1576     167500
#
# [1 rows x 80 columns]

# %%
df[df["Electrical"].isnull()]["Garage Area"]

# no, hat means garage area has a different value missing
# Out:
# 1576    400.0
# Name: Garage Area, dtype: float64

# %%
df [df["Bsmt Half Bath"].isnull()]
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 1341           20        RM          99.0      5940   Pave   NaN       IR1
# 1497           20        RL         123.0     47007   Pave   NaN       IR1
#
#      Land Contour Utilities Lot Config  ... Pool Area Pool QC  Fence  \
# 1341          Lvl    AllPub        FR3  ...         0     NaN  MnPrv
# 1497          Lvl    AllPub     Inside  ...         0     NaN    NaN
#
#      Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  Sale Condition  \
# 1341          NaN        0       4     2008      ConLD         Abnorml
# 1497          NaN        0       7     2008        WD           Normal
#
#       SalePrice
# 1341      79000
# 1497     284700
#
# [2 rows x 80 columns]

# %%
# now we will remove both of the rows using dropan
# we also specify the subset to only drop that data 

df = df.dropna(axis=0, subset=["Electrical", "Garage Area"])

# %%
# lets see how that effected the percent nan list < 1
# dont forget to update the list with new dataframe


percent_nan = percent_missing(df)
percent_nan[percent_nan<1]
# Out:
# Bsmt Unf SF       0.034188
# Total Bsmt SF     0.034188
# BsmtFin SF 2      0.034188
# BsmtFin SF 1      0.034188
# Bsmt Full Bath    0.068376
# Bsmt Half Bath    0.068376
# Mas Vnr Type      0.786325
# Mas Vnr Area      0.786325
# dtype: float64

# %%
# lets visualise the code

plt.figure(figsize=(8,4), dpi=200)
sns.barplot(x=percent_nan.index, y=percent_nan)
plt.xticks(rotation = 90) # will rotate the labels 

# will cut to 1 percent of the data on y
plt.ylim(0,1);

# %%
# now lets take a look at the basement, since one-two house may be missing the basement data


df[df["Bsmt Half Bath"].isnull()]
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 1341           20        RM          99.0      5940   Pave   NaN       IR1
# 1497           20        RL         123.0     47007   Pave   NaN       IR1
#
#      Land Contour Utilities Lot Config  ... Pool Area Pool QC  Fence  \
# 1341          Lvl    AllPub        FR3  ...         0     NaN  MnPrv
# 1497          Lvl    AllPub     Inside  ...         0     NaN    NaN
#
#      Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  Sale Condition  \
# 1341          NaN        0       4     2008      ConLD         Abnorml
# 1497          NaN        0       7     2008        WD           Normal
#
#       SalePrice
# 1341      79000
# 1497     284700
#
# [2 rows x 80 columns]

# %%
# same two rows missing the information


df[df["Bsmt Full Bath"].isnull()]
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 1341           20        RM          99.0      5940   Pave   NaN       IR1
# 1497           20        RL         123.0     47007   Pave   NaN       IR1
#
#      Land Contour Utilities Lot Config  ... Pool Area Pool QC  Fence  \
# 1341          Lvl    AllPub        FR3  ...         0     NaN  MnPrv
# 1497          Lvl    AllPub     Inside  ...         0     NaN    NaN
#
#      Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  Sale Condition  \
# 1341          NaN        0       4     2008      ConLD         Abnorml
# 1497          NaN        0       7     2008        WD           Normal
#
#       SalePrice
# 1341      79000
# 1497     284700
#
# [2 rows x 80 columns]

# %%
df[df["Total Bsmt SF"].isnull()]

# also the same row
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 1341           20        RM          99.0      5940   Pave   NaN       IR1
#
#      Land Contour Utilities Lot Config  ... Pool Area Pool QC  Fence  \
# 1341          Lvl    AllPub        FR3  ...         0     NaN  MnPrv
#
#      Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  Sale Condition  \
# 1341          NaN        0       4     2008      ConLD         Abnorml
#
#       SalePrice
# 1341      79000
#
# [1 rows x 80 columns]

# %%
# BSMT numeric columns ----> fillna 0
# all the columns that have numeric values

bsmt_num_cols = ['BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF','Total Bsmt SF', 'Bsmt Full Bath', 'Bsmt Half Bath']

# fill all those rows with 0 values
df[bsmt_num_cols] = df[bsmt_num_cols].fillna(0)

# %%
# BSMT string columns 
# fill them all with None

bsmt_str_cols =  ['Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin Type 2']
df[bsmt_str_cols] = df[bsmt_str_cols].fillna('None')

# %%
# check if it worked

df[df["Bsmt Full Bath"].isnull()]
# Out:
# Empty DataFrame
# ...

# %%
# dont forget to update the list with new dataframe

percent_nan = percent_missing(df)
percent_nan
# Out:
# Mas Vnr Type      0.786325
# Mas Vnr Area      0.786325
# Garage Type       5.367521
# Garage Yr Blt     5.401709
# Garage Finish     5.401709
# Garage Qual       5.401709
# Garage Cond       5.401709
# Lot Frontage     16.752137
# Fireplace Qu     48.547009
# Fence            80.478632
# Alley            93.230769
# Misc Feature     96.410256
# Pool QC          99.589744
# dtype: float64

# %%
# lets visualise the code

plt.figure(figsize=(8,4), dpi=200)
sns.barplot(x=percent_nan.index, y=percent_nan)
plt.xticks(rotation = 90) # will rotate the labels 

# will cut to 1 percent of the data on y
plt.ylim(0,1);

# %%
# convert string to none 

df["Mas Vnr Type"] = df["Mas Vnr Type"].fillna("None")

# %%
# convert intager to 0

df["Mas Vnr Area"]= df["Mas Vnr Area"].fillna(0)

# %%
percent_nan = percent_missing(df)
percent_nan
# Out:
# Garage Type       5.367521
# Garage Yr Blt     5.401709
# Garage Finish     5.401709
# Garage Qual       5.401709
# Garage Cond       5.401709
# Lot Frontage     16.752137
# Fireplace Qu     48.547009
# Fence            80.478632
# Alley            93.230769
# Misc Feature     96.410256
# Pool QC          99.589744
# dtype: float64

# %%
# lets visualise the code

plt.figure(figsize=(8,4), dpi=200)
sns.barplot(x=percent_nan.index, y=percent_nan)
plt.xticks(rotation = 90) # will rotate the labels
;
# Out:
# ''

# %% [markdown]
# ## Big missing values (rows)

# %%
# looking at the data above, it can be seen that 
# the data is related to garages 
# readeing the description we will identify the nan might be No garage 


# so we will replace missing valuse 
# assuming there is no garage for those numbers

gar_str_cols = ['Garage Type', 'Garage Finish', 'Garage Qual', 'Garage Cond']

# %%
df[gar_str_cols] = df[gar_str_cols].fillna('None')

# %%
percent_nan = percent_missing(df)
percent_nan
# Out:
# Garage Yr Blt     5.401709
# Lot Frontage     16.752137
# Fireplace Qu     48.547009
# Fence            80.478632
# Alley            93.230769
# Misc Feature     96.410256
# Pool QC          99.589744
# dtype: float64

# %%
# for intagers we will replace 0

df['Garage Yr Blt'] = df['Garage Yr Blt'].fillna(0)

# %%
percent_nan = percent_missing(df)
percent_nan
# Out:
# Lot Frontage    16.752137
# Fireplace Qu    48.547009
# Fence           80.478632
# Alley           93.230769
# Misc Feature    96.410256
# Pool QC         99.589744
# dtype: float64

# %%
plt.figure(figsize=(8,4), dpi=200)
sns.barplot(x=percent_nan.index, y=percent_nan)
plt.xticks(rotation = 90) # will rotate the labels
;
# Out:
# ''

# %%
# drop the features (columns that have large percent missing)

df = df.drop(['Fence', 'Alley', 'Misc Feature','Pool QC'], axis=1)

# %%
percent_nan = percent_missing(df)
percent_nan
# Out:
# Lot Frontage    16.752137
# Fireplace Qu    48.547009
# dtype: float64

# %%
plt.figure(figsize=(8,4), dpi=200)
sns.barplot(x=percent_nan.index, y=percent_nan)
plt.xticks(rotation = 90) # will rotate the labels
;
# Out:
# ''

# %%
# lets examin unique values in each column 

df["Fireplace Qu"].value_counts()
# Out:
# Gd    741
# TA    600
# Fa     75
# Po     46
# Ex     43
# Name: Fireplace Qu, dtype: int64

# %%
# since we have strings in column we will fill as None

df["Fireplace Qu"] = df["Fireplace Qu"].fillna("None")

# %%
df["Fireplace Qu"].value_counts()
# Out:
# None    1420
# Gd       741
# TA       600
# Fa        75
# Po        46
# Ex        43
# Name: Fireplace Qu, dtype: int64

# %%
percent_nan = percent_missing(df)
percent_nan
# Out:
# Lot Frontage    16.752137
# dtype: float64

# %%
sns.barplot(x=percent_nan.index, y=percent_nan)
plt.xticks(rotation = 90) # will rotate the labels
;
# Out:
# ''

# %%
df['Lot Frontage'].head(5)
# Out:
# 0    141.0
# 1     80.0
# 2     81.0
# 3     93.0
# 4     74.0
# Name: Lot Frontage, dtype: float64

# %% [markdown]
#  use the neigbhour data
#
# To impute missing data, we need to decide what other filled in (no NaN values) feature most probably relates and is correlated with the missing feature data. In this particular case we will use:
#
# Neighborhood: Physical locations within Ames city limits
#
# LotFrontage: Linear feet of street connected to property
#
# We will operate under the assumption that the Lot Frontage is related to what neighborhood a house is in.

# %%
# we might porve it by create a boxplot and looking at the distributions 

plt.figure(figsize=(8,12), dpi = 300)
sns.boxplot(x = "Lot Frontage", y = "Neighborhood", data = df,orient="h")
;
# Out:
# ''

# %%
# we will use an everage lotfrintage value per neigbour hood
# as you see some a normaly distributed, it is ok to assume 


df.groupby("Neighborhood")["Lot Frontage"].mean()
# Out:
# Neighborhood
# Blmngtn    46.900000
# Blueste    27.300000
# BrDale     21.500000
# BrkSide    55.789474
# ClearCr    88.150000
# CollgCr    71.336364
# Crawfor    69.951807
# Edwards    64.794286
# Gilbert    74.207207
# Greens     41.000000
# GrnHill          NaN
# IDOTRR     62.383721
# Landmrk          NaN
# MeadowV    25.606061
# Mitchel    75.144444
# NAmes      75.210667
# NPkVill    28.142857
# NWAmes     81.517647
# NoRidge    91.629630
# NridgHt    84.184049
# OldTown    61.777293
# SWISU      59.068182
# Sawyer     74.551020
# SawyerW    70.669811
# Somerst    64.549383
# StoneBr    62.173913
# Timber     81.303571
# Veenker    72.000000
# Name: Lot Frontage, dtype: float64

# %%
def fillna (df):
    mean = df.mean()
    val = df.fillna(mean)
    return val

# %%
df["Lot Frontage"] = df.groupby("Neighborhood")["Lot Frontage"].transform(lambda value: value.fillna(value.mean()))

# %%
df.isnull().sum()

# some Lot Frontage values are missing
# Out:
# MS SubClass       0
# MS Zoning         0
# Lot Frontage      3
# Lot Area          0
# Street            0
#                  ..
# Mo Sold           0
# Yr Sold           0
# Sale Type         0
# Sale Condition    0
# SalePrice         0
# Length: 76, dtype: int64

# %%
df["Lot Frontage"] = df["Lot Frontage"].fillna(0)

# %%
df.isnull().sum()
# Out:
# MS SubClass       0
# MS Zoning         0
# Lot Frontage      0
# Lot Area          0
# Street            0
#                  ..
# Mo Sold           0
# Yr Sold           0
# Sale Type         0
# Sale Condition    0
# SalePrice         0
# Length: 76, dtype: int64
